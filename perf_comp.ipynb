# %%
import pandas as pd

# %%
df = pd.read_csv('./perf_summary.csv', header=None)

# %%
df_ml = pd.read_csv('./temp.csv')

# %%
df.columns=['cancer','epoch','valid_DL','test_DL','tr','val','test']

# %%
df.cancer = df.cancer.apply(lambda x: x.split('.')[0])

# %%
pd.merge(df_ml, df, on='cancer')
# Out:
#     Unnamed: 0         cancer     train    test_x  epoch  valid_DL   test_DL
# 0            2      TCGA-BLCA  0.694997  0.917630     86  0.736994  0.430077  \
# 1            3     TCGA-BRAIN  0.599536  0.497878     99  0.895688  0.894410
# 2            4      TCGA-BRCA  0.847847  0.395131     94  0.779817  0.595054
# 3            5      TCGA-CESC  0.816809  0.608122     62  0.911765  0.363636
# 4            8  TCGA-COADREAD  0.553362  0.766917      0  0.806854  0.467314
# 5           10      TCGA-ESCA  0.782911  0.400927     60  1.000000  0.523810
# 6           14    TCGA-KIDNEY  0.823127  0.623711     29  0.964286  0.639423
# 7           15      TCGA-KIRC  0.896979  0.581818     93  0.888889  0.482993
# 8           16      TCGA-KIRP  0.900232  0.551899     27  0.867925  0.160714
# 9           18       TCGA-LGG  0.775570  0.288760     75  0.945652  0.869955
# 10          19      TCGA-LIHC  0.618444  0.509412     25  0.801980  0.720000
# ...

# %%
df_ml
# Out:
#     Unnamed: 0         cancer     train      test
# 0            1       TCGA-ACC  0.800152  0.555113
# 1            2      TCGA-BLCA  0.694997  0.917630
# 2            3     TCGA-BRAIN  0.599536  0.497878
# 3            4      TCGA-BRCA  0.847847  0.395131
# 4            5      TCGA-CESC  0.816809  0.608122
# 5            8  TCGA-COADREAD  0.553362  0.766917
# 6            9      TCGA-DLBC  0.818842  0.318182
# 7           10      TCGA-ESCA  0.782911  0.400927
# 8           14    TCGA-KIDNEY  0.823127  0.623711
# 9           15      TCGA-KIRC  0.896979  0.581818
# 10          16      TCGA-KIRP  0.900232  0.551899
# 11          18       TCGA-LGG  0.775570  0.288760
# 12          19      TCGA-LIHC  0.618444  0.509412
# 13          20      TCGA-LUAD  0.647489  0.699146
# 14          21      TCGA-LUNG  0.866084  0.535581
# 15          22      TCGA-LUSC  0.874626  0.676471
# 16          24        TCGA-OV  0.623665  0.806911
# 17          25      TCGA-PAAD  0.868453  0.397331
# ...
